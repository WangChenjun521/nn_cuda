# %%
# %%capture
# !python pytorch/setup.py install
# Out:
# running install
# /home/wangchenjun/.conda/envs/NNRT/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /home/wangchenjun/.conda/envs/NNRT/lib/python3.8/site-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# writing nn_cuda.egg-info/PKG-INFO
# writing dependency_links to nn_cuda.egg-info/dependency_links.txt
# writing top-level names to nn_cuda.egg-info/top_level.txt
# reading manifest file 'nn_cuda.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'nn_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# ...

# %%
# !python python/main2.py
# Out:
# Running cuda...
# name: NVIDIA GeForce GTX 1080 Ti
# totalGlobalMem: 11719409664
# regsPerBlock: 65536
# warpSize: 32
# memPitch: 2147483647
#
# 一个线程块中可使用的最大共享内存
# devProps.sharedMemPerBlock: 49152
#
# 一个线程块中可包含的最大线程数量
# maxThreadsPerBlock: 1024
#
# 多维线程块数组中每一维可包含的最大线程数量
# maxThreadsDim[0]: 1024
# maxThreadsDim[1]: 1024
# maxThreadsDim[2]: 64
#
# 一个线程格中每一维可包含的最大线程块数量
# maxGridSize[0]: 2147483647
# maxGridSize[1]: 65535
# maxGridSize[2]: 65535
#
# clockRate: 1645000
# totalConstMem: 65536
# textureAlignment: 512
#
# 计算能力：6.1
#
# minor: 1
# texturePitchAlignment: 32
# deviceOverlap: 1
# multiProcessorCount: 28
# kernelExecTimeoutEnabled: 1
# integrated: 0
# canMapHostMemory: 1
# computeMode: 0
# maxTexture1D: 131072
# maxTexture1DMipmap: 16384
# maxTexture1DLinear: 268435456
# maxTexture2D: 0x7ffd5014a684
# maxTexture2DMipmap: 0x7ffd5014a68c
# maxTexture2DLinear: 0x7ffd5014a694
# maxTexture2DGather: 0x7ffd5014a6a0
# maxTexture3D: 0x7ffd5014a6a8
# maxTexture3DAlt: 0x7ffd5014a6b4
# ...

# %%
# !git status
# !git add .
# !git commit -m "auto update"
# !git push origin master
